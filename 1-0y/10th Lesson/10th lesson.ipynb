# %%
import pandas as pd 
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
scaler=MinMaxScaler()
encoder=LabelEncoder()

# %%
df=pd.read_csv('student-por.csv', sep=';')

# %% [markdown]
# PreProcessing

# %%
df.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      24
# G1            17
# G2            16
# G3            17
# dtype: int64

# %%
# Filling Missing Values
for col in df.columns:
    if df[col].isnull().any():
        if df[col].dtype=='object':
            df[col].fillna(df[col].mode()[0], inplace=True)
        else:
            df[col].fillna(df[col].mean(), inplace=True)
# Out:
# C:\Users\maxma\AppData\Local\Temp\ipykernel_72212\3412402607.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
#Encoding Object values to numeric values
for col in df.columns:
    if df[col].dtype=='object':
        if df[col].nunique()<2:
            dummies=pd.get_dummies(df[col], prefix=col, dtype=int)
            df=pd.concat([df.drop(columns=col), dummies], axis=1)
        else:
            df[col]=encoder.fit_transform(df[col])

# %%
#Scaling large numeric values
numeric_cols=df.select_dtypes(include=['float64', 'int64']).columns.drop('health')
df[numeric_cols]=scaler.fit_transform(df[numeric_cols])

# %% [markdown]
# Modelling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    float64
#  1   sex         649 non-null    float64
#  2   age         649 non-null    float64
#  3   address     649 non-null    float64
#  4   famsize     649 non-null    float64
#  5   Pstatus     649 non-null    float64
#  6   Medu        649 non-null    float64
#  7   Fedu        649 non-null    float64
#  8   Mjob        649 non-null    float64
#  9   Fjob        649 non-null    float64
#  10  reason      649 non-null    float64
#  11  guardian    649 non-null    float64
#  12  traveltime  649 non-null    float64
#  13  studytime   649 non-null    float64
#  14  failures    649 non-null    float64
#  15  schoolsup   649 non-null    float64
#  16  famsup      649 non-null    float64
#  17  paid        649 non-null    float64
#  18  activities  649 non-null    float64
#  19  nursery     649 non-null    float64
#  20  higher      649 non-null    float64
#  21  internet    649 non-null    float64
#  22  romantic    649 non-null    float64
#  23  famrel      649 non-null    float64
#  24  freetime    649 non-null    float64
#  25  goout       649 non-null    float64
#  26  Dalc        649 non-null    float64
#  27  Walc        649 non-null    float64
#  28  health      649 non-null    int64
#  29  absences    649 non-null    float64
#  30  G1          649 non-null    float64
#  31  G2          649 non-null    float64
#  32  G3          649 non-null    float64
# dtypes: float64(32), int64(1)
# memory usage: 167.4 KB

# %%
df.head()
# Out:
#    school  sex       age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0     0.0  0.0  0.428571      1.0      0.0      0.0  1.00  1.00  0.00  1.00
# 1     0.0  0.0  0.285714      1.0      0.0      1.0  0.25  0.25  0.00  0.50
# 2     0.0  0.0  0.000000      1.0      1.0      1.0  0.25  0.25  0.00  0.50
# 3     0.0  0.0  0.000000      1.0      0.0      1.0  1.00  0.50  0.25  0.75
# 4     0.0  0.0  0.142857      1.0      0.0      1.0  0.75  0.75  0.50  0.50
#
#    ...  famrel  freetime     goout  Dalc  Walc  health  absences        G1  \
# 0  ...    0.75      0.50  0.750000  0.00  0.00       3    0.1250  0.000000
# 1  ...    1.00      0.50  0.500000  0.00  0.00       3    0.0625  0.473684
# 2  ...    0.75      0.50  0.250000  0.25  0.50       3    0.1875  0.631579
# 3  ...    0.50      0.25  0.250000  0.00  0.00       5    0.0000  0.736842
# 4  ...    0.75      0.50  0.548666  0.00  0.25       5    0.0000  0.578947
#
#          G2        G3
# 0  0.578947  0.578947
# 1  0.578947  0.578947
# 2  0.684211  0.631579
# 3  0.736842  0.736842
# 4  0.684211  0.684211
#
# [5 rows x 33 columns]

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.linear_model import LinearRegression 
model=LogisticRegression()
from sklearn.model_selection import train_test_split

# %%
x=df.drop('health', axis=1) 
y=df['health']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.fit(x_test, y_test)
# Out:
# LogisticRegression()
